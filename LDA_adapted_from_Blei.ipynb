# %%
import re
import os

#Opens a file in read mode  

count = 0;  
   
vocab = {}
ct = 0
file = open("dictnostops.txt", "r")
for line in file:
    words = line.split(" ")
    for i in words:
        if len(i) > 3:
            i = i.lower()
            i = re.sub(r'[^a-z]', '', i)
            vocab[i] = ct
            ct += 1
dict_len = ct
file.close()
print("Size of dictionary: " + str(dict_len))
print(vocab)


directory = "books"

book = []
page_length = 0
ct = 0
page = []

for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f):
        file = open(f, "r")    

    #Gets each line till end of file is reached  
    for line in file:  
        #Splits each line into words  
        words = line.split(" ");  
        for i in words:
            i = i.lower()
            i = re.sub(r'[^a-z]', '', i)
            if len(i) != 0:
                page_length += 1
                if i in vocab:
                    if page_length < 1000:
                        page.append(i)
                    else:
                        book.append(page)
                        page = []
                        page_length = 0

    book.append(page)

count = 0
for page in book:
    count += len(page)

print("Number of words present in given file: " + str(count))
file.close();  
print(book[0])
print(len(book))
# Out:
# Size of dictionary: 7702
# {'writings': 0, 'yellow': 1, 'four': 2, 'woods': 3, 'hanging': 4, 'marching': 5, 'looking': 6, 'rouse': 7, 'lord': 8, 'sagde': 9, 'meadows': 10, 'sinking': 11, 'foul': 12, 'bringing': 13, 'disturb': 14, 'uttering': 15, 'scholar': 16, 'wooden': 17, 'wednesday': 18, 'haben': 19, 'persisted': 20, 'succession': 21, 'specially': 22, 'nigh': 23, 'tired': 24, 'miller': 25, 'bacon': 26, 'pulse': 27, 'elegant': 28, 'second': 29, 'valiant': 30, 'sailed': 31, 'errors': 32, 'thunder': 33, 'cooking': 34, 'contributed': 35, 'fingers': 36, 'increasing': 37, 'etexts': 38, 'dort': 39, 'hero': 40, 'leaning': 41, 'herd': 42, 'reported': 43, 'china': 44, 'herr': 45, 'substance': 46, 'elaborate': 47, 'climbed': 48, 'reports': 49, 'controversy': 50, 'ueber': 51, 'natures': 52, 'military': 53, 'criticism': 54, 'golden': 55, 'divide': 56, 'explained': 57, 'replace': 58, 'brought': 59, 'stern': 60, 'spoke': 61, 'leurs': 62, 'music': 63, 'telegraph': 64, 'mystic': 65, 'strike': 66, 'paperwork': 67, 'holy': 68, 'successful': 69, 'brings': 70, 'hurt': 71, 'glass': 72, 'aux': 73, 'midst': 74, 'hold': 75, 'circumstances': 76, 'locked': 77, 'pursue': 78, 'blade': 79, 'plunged': 80, 'mots': 81, 'leaped': 82, 'revenues': 83, 'avaient': 84, 'misfortunes': 85, 'owes': 86, 'unjust': 87, 'household': 88, 'artillery': 89, 'organized': 90, 'caution': 91, 'kingdoms': 92, 'absolute': 93, 'provincial': 94, 'hoe': 95, 'groaned': 96, 'hon': 97, 'travel': 98, 'damage': 99, 'machine': 100, 'hot': 101, 'augen': 102, 'significance': 103, 'dignified': 104, 'beauty': 105, 'shores': 106, 'wrong': 107, 'destined': 108, 'poboxcom': 109, 'types': 110, 'effective': 111, 'endeavoured': 112, 'youths': 113, 'revolt': 114, 'headquarters': 115, 'baggage': 116, 'keeps': 117, 'democratic': 118, 'wing': 119, 'wind': 120, 'wine': 121, 'welcomed': 122, 'dreamed': 123, 'confederate': 124, 'vary': 125, 'peut': 126, 'tandis': 127, 'fidelity': 128, 'wrought': 129, 'admirably': 130, 'fit': 131, 'heretofore': 132, 'fix': 133, 'rescued': 134, 'fig': 135, 'nobler': 136, 'wales': 137, 'hidden': 138, 'admirable': 139, 'easier': 140, 'grievous': 141, 'corridor': 142, 'detachment': 143, 'effects': 144, 'schools': 145, 'sixteen': 146, 'silver': 147, 'prize': 148, 'represents': 149, 'crops': 150, 'arrow': 151, 'blushed': 152, 'preceded': 153, 'financial': 154, 'series': 155, 'allah': 156, 'commons': 157, 'fortnight': 158, 'cathedral': 159, 'aurait': 160, 'ring': 161, 'whip': 162, 'borne': 163, 'misfortune': 164, 'excepting': 165, 'mason': 166, 'toute': 167, 'encourage': 168, 'millions': 169, 'foundation': 170, 'clarence': 171, 'assured': 172, 'threatened': 173, 'fugitive': 174, 'syn': 175, 'faculties': 176, 'expends': 177, 'crowned': 178, 'estimate': 179, 'universally': 180, 'enormous': 181, 'ate': 182, 'att': 183, 'disturbed': 184, 'speedy': 185, 'mademoiselle': 186, 'wash': 187, 'service': 188, 'xii': 189, 'engagement': 190, 'needed': 191, 'master': 192, 'listed': 193, 'xiv': 194, 'gilbert': 195, 'legs': 196, 'bitter': 197, 'listen': 198, 'wisdom': 199, 'motionless': 200, 'positively': 201, 'peril': 202, 'showed': 203, 'coward': 204, 'tree': 205, 'nations': 206, 'project': 207, 'idle': 208, 'exclaimed': 209, 'endure': 210, 'tres': 211, 'feeling': 212, 'este': 213, 'esta': 214, 'boston': 215, 'aprs': 216, 'notwithstanding': 217, 'dozen': 218, 'affairs': 219, 'wholesome': 220, 'responsible': 221, 'eagerly': 222, 'recommended': 223, 'causing': 224, 'absorbed': 225, 'amusing': 226, 'doors': 227, 'shall': 228, 'object': 229, 'victoria': 230, 'doit': 231, 'swiss': 232, 'mouth': 233, 'letter': 234, 'entry': 235, 'shalt': 236, 'grove': 237, 'professor': 238, 'camp': 239, 'spend': 240, 'nineteenth': 241, 'scream': 242, 'incomplete': 243, 'marvel': 244, 'saying': 245, 'insects': 246, 'meetings': 247, 'tempted': 248, 'prit': 249, 'lessons': 250, 'orleans': 251, 'touches': 252, 'busy': 253, 'louise': 254, 'quaint': 255, 'cousins': 256, 'mens': 257, 'bush': 258, 'bliss': 259, 'touched': 260, 'rich': 261, 'heartily' ...
# Number of words present in given file: 321245
# ['project', 'gutenberg', 'ebook', 'adventures', 'ebook', 'united', 'states', 'world', 'cost', 'restrictions', 'whatsoever', 'copy', 'give', 'away', 'terms', 'project', 'gutenberg', 'license', 'ebook', 'online', 'located', 'united', 'states', 'check', 'laws', 'country', 'located', 'ebook', 'title', 'adventures', 'author', 'lewis', 'release', 'date', 'june', 'ebook', 'recently', 'updated', 'march', 'language', 'english', 'arthur', 'david', 'start', 'project', 'gutenberg', 'ebook', 'adventures', 'illustration', 'adventures', 'lewis', 'edition', 'contents', 'chapter', 'chapter', 'pool', 'tears', 'chapter', 'iii', 'long', 'tale', 'chapter', 'sends', 'little', 'bill', 'chapter', 'advice', 'chapter', 'pig', 'pepper', 'chapter', 'vii', 'mad', 'chapter', 'viii', 'queens', 'chapter', 'mock', 'story', 'chapter', 'chapter', 'stole', 'chapter', 'xii', 'evidence', 'chapter', 'alice', 'beginning', 'get', 'tired', 'sitting', 'sister', 'bank', 'twice', 'book', 'sister', 'reading', 'pictures', 'book', 'thought', 'alice', 'pictures', 'considering', 'mind', 'hot', 'day', 'made', 'feel', 'sleepy', 'stupid', 'pleasure', 'making', 'worth', 'trouble', 'getting', 'picking', 'suddenly', 'white', 'pink', 'eyes', 'ran', 'close', 'remarkable', 'alice', 'think', 'hear', 'say', 'dear', 'dear', 'shall', 'late', 'thought', 'occurred', 'ought', 'wondered', 'time', 'quite', 'natural', 'actually', 'watch', 'looked', 'hurried', 'alice', 'started', 'feet', 'flashed', 'mind', 'seen', 'watch', 'take', 'burning', 'curiosity', 'ran', 'field', 'fortunately', 'just', 'time', 'see', 'large', 'hedge', 'moment', 'went', 'alice', 'considering', 'world', 'get', 'went', 'straight', 'like', 'suddenly', 'suddenly', 'alice', 'moment', 'think', 'stopping', 'found', 'falling', 'deep', 'deep', 'fell', 'slowly', 'plenty', 'time', 'went', 'look', 'wonder', 'going', 'happen', 'first', 'tried', 'look', 'make', 'coming', 'dark', 'see', 'looked', 'sides', 'noticed', 'filled', 'saw', 'pictures', 'hung', 'jar', 'passed', 'orange', 'great', 'disappointment', 'empty', 'like', 'drop', 'jar', 'fear', 'killing', 'somebody', 'underneath', 'managed', 'put', 'fell', 'past', 'thought', 'alice', 'fall', 'shall', 'think', 'stairs', 'brave', 'theyll', 'think', 'home', 'wouldnt', 'say', 'fell', 'top', 'house', 'likely', 'true', 'fall', 'come', 'end', 'wonder', 'miles', 'ive', 'fallen', 'time', 'said', 'aloud', 'getting', 'centre', 'earth', 'let', 'see', 'four', 'thousand', 'miles', 'think', 'see', 'alice', 'learnt', 'things', 'sort', 'lessons', 'good', 'opportunity', 'showing', 'knowledge', 'listen', 'good', 'practice', 'say', 'thats', 'right', 'wonder', 'latitude', 'longitude', 'ive', 'got', 'alice', 'idea', 'latitude', 'longitude', 'thought', 'nice', 'grand', 'words', 'say', 'presently', 'wonder', 'shall', 'fall', 'right', 'earth', 'funny', 'come', 'people', 'walk', 'heads', 'downward', 'think', 'glad', 'listening', 'time', 'didnt', 'sound', 'right', 'word', 'shall', 'ask', 'name', 'country', 'know', 'please', 'maam', 'new', 'australia', 'tried', 'youre', 'falling', 'air', 'think', 'manage', 'ignorant', 'little', 'girl', 'shell', 'think', 'asking', 'ask', 'shall', 'see', 'written', 'alice', 'soon', 'talking', 'think']
# 964

# %%
import numpy as np
from scipy.special import gammaln, psi

np.random.seed(100000001)
meanchangethresh = 0.001

def dirichlet_expectation(alpha):
    """
    For a vector theta ~ Dir(alpha), computes E[log(theta)] given alpha.
    """
    if (len(alpha.shape) == 1):
        return(psi(alpha) - psi(np.sum(alpha)))
    return(psi(alpha) - psi(np.sum(alpha, 1))[:, np.newaxis])

# %%
import string

def parse_doc_list(docs, vocab):
    """
    Parse a document into a list of word ids and a list of counts,
    or parse a set of documents into two lists of lists of word ids
    and counts.

    Arguments: 
    docs:  List of D documents. Each document must be represented as
           a single string. (Word order is unimportant.) Any
           words not in the vocabulary will be ignored.
    vocab: Dictionary mapping from words to integer ids.

    Returns a pair of lists of lists. 

    The first, wordids, says what vocabulary tokens are present in
    each document. wordids[i][j] gives the jth unique token present in
    document i. (Don't count on these tokens being in any particular
    order.)

    The second, wordcts, says how many times each vocabulary token is
    present. wordcts[i][j] is the number of times that the token given
    by wordids[i][j] appears in document i.
    """
    #we will use docs as a selection of pages
    
    if (type(docs).__name__ == 'str'):
        temp = list()
        temp.append(docs)
        docs = temp

    D = len(docs)
    
    wordids = list()
    wordcts = list()
    for d in range(0, D):
        words = docs[d]
        ddict = dict()
        for word in words:
            if (word in vocab):
                wordtoken = vocab[word]
                if (not wordtoken in ddict):
                    ddict[wordtoken] = 0
                ddict[wordtoken] += 1
        wordids.append(ddict.keys())
        wordcts.append(ddict.values())

    return((wordids, wordcts))

# %%
import numpy as np

def do_e_step(wordids, wordcts, lambda_, expElogbeta, alpha, K):
        batchD = len(wordids)

        # Initialize the variational distribution q(theta|gamma) for
        # the mini-batch
        gamma = 1*np.random.gamma(100., 1./100., (batchD, K))
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = np.exp(Elogtheta)

        sstats = np.zeros(lambda_.shape)
        # Now, for each document d update that document's gamma and phi
        it = 0
        meanchange = 0
        for d in range(0, batchD):
            #print(sum(wordcts[d]))
            # These are mostly just shorthand (but might help cache locality)
            ids = np.array(list(wordids[d]))
            cts = np.array(list(wordcts[d]))

            gammad = gamma[d, :]
            Elogthetad = Elogtheta[d, :]
            expElogthetad = expElogtheta[d, :]
            expElogbetad = expElogbeta[:, ids]
            
            # The optimal phi_{dwk} is proportional to 
            # expElogthetad_k * expElogbetad_w. phinorm is the normalizer.
            phinorm = np.dot(expElogthetad, expElogbetad) + 1e-100
            # Iterate between gamma and phi until convergence
            for it in range(0, 100):
                lastgamma = gammad
                # We represent phi implicitly to save memory and time.
                # Substituting the value of the optimal phi back into
                # the update for gamma gives this update. Cf. Lee&Seung 2001.
                gammad = alpha + expElogthetad * \
                    np.dot(cts / phinorm, expElogbetad.T)
                #print gammad[:, n.newaxis]
                Elogthetad = dirichlet_expectation(gammad)
                expElogthetad = np.exp(Elogthetad)
                phinorm = np.dot(expElogthetad, expElogbetad) + 1e-100
                # If gamma hasn't changed much, we're done.
                meanchange = np.mean(abs(gammad - lastgamma))
                if (meanchange < meanchangethresh):
                    break
            gamma[d, :] = gammad
            # Contribution of document d to the expected sufficient
            # statistics for the M step.
            
            sstats[:, ids] += np.outer(expElogthetad.T, cts/phinorm)

        # This step finishes computing the sufficient statistics for the
        # M step, so that
        # sstats[k, w] = \sum_d n_{dw} * phi_{dwk} 
        # = \sum_d n_{dw} * exp{Elogtheta_{dk} + Elogbeta_{kw}} / phinorm_{dw}.
        sstats = sstats * expElogbeta

        return((gamma, sstats))

# %%
def do_e_step_docs(docs, vocab, lambda_, expElogbeta, alpha, K):
       """
       Given a mini-batch of documents, estimates the parameters
       gamma controlling the variational distribution over the topic
       weights for each document in the mini-batch.

       Arguments:
       docs:  List of D documents. Each document must be represented
              as a string. (Word order is unimportant.) Any
              words not in the vocabulary will be ignored.

       Returns a tuple containing the estimated values of gamma,
       as well as sufficient statistics needed to update lambda.
       """
       # This is to handle the case where someone just hands us a single
       # document, not in a list.

       (wordids, wordcts) = parse_doc_list(docs, vocab)

       return do_e_step(wordids, wordcts, lambda_, expElogbeta, alpha, K)

# %%
def approx_bound(wordids, wordcts, gamma, vocab, Elogbeta, alpha, K, D, eta, W, lambda_):
        """
        Estimates the variational bound over *all documents* using only
        the documents passed in as "docs." gamma is the set of parameters
        to the variational distribution q(theta) corresponding to the
        set of documents passed in.

        The output of this function is going to be noisy, but can be
        useful for assessing convergence.
        """

        # This is to handle the case where someone just hands us a single
        # document, not in a list.

        batchD = len(wordids)

        score = 0
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = np.exp(Elogtheta)

        # E[log p(docs | theta, beta)]
        for d in range(0, batchD):
            gammad = gamma[d, :]
            ids = np.array(list(wordids[d]))
            cts = np.array(list(wordcts[d]))
            phinorm = np.zeros(len(ids))
            for i in range(0, len(ids)):
                temp = Elogtheta[d, :] + Elogbeta[:, ids[i]]
                tmax = max(temp)
                phinorm[i] = np.log(sum(np.exp(temp - tmax))) + tmax
            score += np.sum(cts * phinorm)
#             oldphinorm = phinorm
#             phinorm = n.dot(expElogtheta[d, :], self._expElogbeta[:, ids])
#             print oldphinorm
#             print n.log(phinorm)
#             score += n.sum(cts * n.log(phinorm))

        # E[log p(theta | alpha) - log q(theta | gamma)]
        score += np.sum((alpha - gamma)*Elogtheta)
        score += np.sum(gammaln(gamma) - gammaln(alpha))
        score += sum(gammaln(alpha*K) - gammaln(np.sum(gamma, 1)))

        # Compensate for the subsampling of the population of documents
        score = score * D / len(wordids)

        # E[log p(beta | eta) - log q (beta | lambda)]
        score = score + np.sum((eta-lambda_)*Elogbeta)
        score = score + np.sum(gammaln(lambda_) - gammaln(eta))
        score = score + np.sum(gammaln(eta*W) - 
                              gammaln(np.sum(lambda_, 1)))

        return(score)

# %%
def approx_bound_docs(docs, gamma, vocab, Elogbeta, alpha, K, D, eta, W, lambda_):
        """
        Estimates the variational bound over *all documents* using only
        the documents passed in as "docs." gamma is the set of parameters
        to the variational distribution q(theta) corresponding to the
        set of documents passed in.

        The output of this function is going to be noisy, but can be
        useful for assessing convergence.
        """

        # This is to handle the case where someone just hands us a single
        # document, not in a list.

        (wordids, wordcts) = parse_doc_list(docs, vocab)
        batchD = len(docs)

        score = 0
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = np.exp(Elogtheta)

        # E[log p(docs | theta, beta)]
        for d in range(0, batchD):
            gammad = gamma[d, :]
            ids = np.array(list(wordids[d]))
            cts = np.array(list(wordcts[d]))
            phinorm = np.zeros(len(ids))
            for i in range(0, len(ids)):
                temp = Elogtheta[d, :] + Elogbeta[:, ids[i]]
                tmax = max(temp)
                phinorm[i] = np.log(sum(np.exp(temp - tmax))) + tmax
            score += np.sum(cts * phinorm)
#             oldphinorm = phinorm
#             phinorm = n.dot(expElogtheta[d, :], self._expElogbeta[:, ids])
#             print oldphinorm
#             print n.log(phinorm)
#             score += n.sum(cts * n.log(phinorm))

        # E[log p(theta | alpha) - log q(theta | gamma)]
        score += np.sum((alpha - gamma)*Elogtheta)
        score += np.sum(gammaln(gamma) - gammaln(alpha))
        score += sum(gammaln(alpha*K) - gammaln(np.sum(gamma, 1)))

        # Compensate for the subsampling of the population of documents
        score = score * D / len(docs)

        # E[log p(beta | eta) - log q (beta | lambda)]
        score = score + np.sum((eta-lambda_)*Elogbeta)
        score = score + np.sum(gammaln(lambda_) - gammaln(eta))
        score = score + np.sum(gammaln(eta*W) - 
                              gammaln(np.sum(lambda_, 1)))

        return(score)

# %%
def update_lambda(wordids, wordcts, tau0, updatect, kappa, lambda_, expElogbeta, alpha, K, Elogbeta, D, eta, W):
        """
        First does an E step on the mini-batch given in wordids and
        wordcts, then uses the result of that E step to update the
        variational parameter matrix lambda.

        Arguments:
        docs:  List of D documents. Each document must be represented
               as a string. (Word order is unimportant.) Any
               words not in the vocabulary will be ignored.

        Returns gamma, the parameters to the variational distribution
        over the topic weights theta for the documents analyzed in this
        update.

        Also returns an estimate of the variational bound for the
        entire corpus for the OLD setting of lambda based on the
        documents passed in. This can be used as a (possibly very
        noisy) estimate of held-out likelihood.
        """

        # rhot will be between 0 and 1, and says how much to weight
        # the information we got from this mini-batch.
        rhot = pow(tau0 + updatect, -kappa)

        # Do an E step to update gamma, phi | lambda for this
        # mini-batch. This also returns the information about phi that
        # we need to update lambda.
        (gamma, sstats) = do_e_step(wordids, wordcts, lambda_, expElogbeta, alpha, K)
        # Estimate held-out likelihood for current values of lambda.
        bound = approx_bound(wordids, wordcts, gamma, vocab, Elogbeta, alpha, K, D, eta, W, lambda_)
        # Update lambda based on documents.
        lambda_ = lambda_ * (1-rhot) + \
            rhot * (eta + D * sstats / len(wordids))
        Elogbeta = dirichlet_expectation(lambda_)
        expElogbeta = np.exp(Elogbeta)
        updatect += 1

        return(gamma, bound, rhot, lambda_, Elogbeta, expElogbeta, updatect)

# %% [markdown]
# Notes:
# Digamma function = first derivative of log Gamma function
# $$
# \Psi(z) = \frac{\Gamma'(z)}{\Gamma(z)} \sim \text{ln}z - \frac{1}{2z}
# $$

# %%
import numpy as np
import scipy
from scipy.special import gammaln, psi

np.random.seed(1)

topic = np.random.choice(list(vocab.keys()), 20, replace=False)


K = len(topic)
W = dict_len
D = len(topic)
alpha = 1/K
eta = 1/K
tau = 1024 #just some number
kappa = 0.7 #p
updatect = 0

lambda_ = 1*np.random.gamma(100., 1./100., (K, W))
Elogbeta = dirichlet_expectation(lambda_)
expElogbeta = np.exp(Elogbeta)

beta = np.random.dirichlet(np.repeat(1/K,K), K)
theta = np.random.dirichlet(np.repeat(1/K,K), K)

N = 20

rhot = pow(tau + updatect, -kappa)
(wordids, wordcts) = parse_doc_list(book, vocab)
val = []

for i in range(500):
    (gamma, bound, rhot, lambda_, Elogbeta, expElogbeta, updatect) = update_lambda(wordids, wordcts, tau, updatect, kappa, lambda_, expElogbeta, alpha, K, Elogbeta, D, eta, W)
    score = approx_bound_docs(book, gamma, vocab, Elogbeta, alpha, K, D, eta, W, lambda_)
    val.append(score)

import matplotlib.pyplot as plt
plt.plot(val)
plt.show()

"""
for i in range(N):
    page = book[np.random.randint(0, len(book))]
    g = np.ones(K)
    phi = np.zeros((N,K))
    for j in range(200):
        n = 0
        for word in np.random.choice(page, N, replace=False):
            phi[n] = np.exp(1)
            #print(phi)
            n += 1
"""
# Out:
# '\nfor i in range(N):\n    page = book[np.random.randint(0, len(book))]\n    g = np.ones(K)\n    phi = np.zeros((N,K))\n    for j in range(200):\n        n = 0\n        for word in np.random.choice(page, N, replace=False):\n            phi[n] = np.exp(1)\n            #print(phi)\n            n += 1\n'

# %%
def print_topic(vocab, lambda_):
    """
    Displays topics fit by onlineldavb.py. The first column gives the
    (expected) most prominent words in the topics, the second column
    gives their (expected) relative prominence.
    """

    flipped_vocab = dict([(value, key) for key, value in vocab.items()])

    for k in range(0, len(lambda_)):
        lambdak = list(lambda_[k, :])
        lambdak = lambdak / sum(lambdak)
        temp = zip(lambdak, range(0, len(lambdak)))
        temp = sorted(temp, key = lambda x: x[0], reverse=True)
        print('topic %d:' % (k))
        # feel free to change the "53" here to whatever fits your screen nicely.
        for i in range(min(10, len(lambdak))):
            word_index = temp[i][1]
            word_probability = temp[i][0]
            
            # Using get to handle potential KeyError if word_index is not in vocab
            word = flipped_vocab[word_index]
            
            print(f'{word:20}  \t---\t  {word_probability:.4f}')
        print(np.size(temp))

# %%
print(print(vocab.items), lambda_.shape)
print_topic(vocab, lambda_)
# Out:
# <built-in method items of dict object at 0x0000013F6AAE54C0>
# None (20, 7702)
# topic 0:
# entrance              	---	  0.0002
# threats               	---	  0.0002
# message               	---	  0.0001
# thou                  	---	  0.0001
# thieves               	---	  0.0001
# graham                	---	  0.0001
# edinburgh             	---	  0.0001
# invented              	---	  0.0001
# chercher              	---	  0.0001
# displaying            	---	  0.0001
# 15404
# topic 1:
# good                  	---	  0.0002
# forme                 	---	  0.0002
# witch                 	---	  0.0002
# transparent           	---	  0.0001
# compilation           	---	  0.0001
# warmly                	---	  0.0001
# horrid                	---	  0.0001
# wretch                	---	  0.0001
# cynthia               	---	  0.0001
# deprive               	---	  0.0001
# 15404
# topic 2:
# natures               	---	  0.0002
# pages                 	---	  0.0001
# absorbed              	---	  0.0001
# river                 	---	  0.0001
# invited               	---	  0.0001
# divided               	---	  0.0001
# modify                	---	  0.0001
# overhead              	---	  0.0001
# closer                	---	  0.0001
# prevailed             	---	  0.0001
# 15404
# topic 3:
# said                  	---	  0.0077
# like                  	---	  0.0049
# man                   	---	  0.0046
# time                  	---	  0.0045
# know                  	---	  0.0039
# see                   	---	  0.0039
# little                	---	  0.0038
# old                   	---	  0.0035
# shall                 	---	  0.0034
# life                  	---	  0.0034
# 15404
# topic 4:
# quit                  	---	  0.0002
# questioned            	---	  0.0002
# civilization          	---	  0.0002
# agreeable             	---	  0.0002
# fail                  	---	  0.0002
# brief                 	---	  0.0001
# coarse                	---	  0.0001
# unbroken              	---	  0.0001
# fly                   	---	  0.0001
# beautiful             	---	  0.0001
# 15404
# topic 5:
# lance                 	---	  0.0002
# familiar              	---	  0.0002
# rounded               	---	  0.0002
# wondered              	---	  0.0001
# existing              	---	  0.0001
# sergeant              	---	  0.0001
# henry                 	---	  0.0001
# liberties             	---	  0.0001
# provincial            	---	  0.0001
# pushing               	---	  0.0001
# 15404
# topic 6:
# kick                  	---	  0.0002
# prescribed            	---	  0.0002
# joie                  	---	  0.0002
# engines               	---	  0.0001
# bonnet                	---	  0.0001
# forget                	---	  0.0001
# stationed             	---	  0.0001
# listening             	---	  0.0001
# fallait               	---	  0.0001
# considered            	---	  0.0001
# 15404
# topic 7:
# yellow                	---	  0.0001
# first                 	---	  0.0001
# ayant                 	---	  0.0001
# shot                  	---	  0.0001
# adventures            	---	  0.0001
# made                  	---	  0.0001
# potatoes              	---	  0.0001
# negligence            	---	  0.0001
# found                 	---	  0.0001
# bills                 	---	  0.0001
# 15404
# topic 8:
# passion               	---	  0.0002
# north                 	---	  0.0002
# thy                   	---	  0.0002
# detail                	---	  0.0002
# delicacy              	---	  0.0001
# jefferson             	---	  0.0001
# purposes              	---	  0.0001
# tract                 	---	  0.0001
# kindly                	---	  0.0001
# swinging              	---	  0.0001
# 15404
# topic 9:
# alice                 	---	  0.0002
# till                  	---	  0.0002
# rejoice               	---	  0.0002
# stayed                	---	  0.0002
# duly                  	---	  0.0002
# half                  	---	  0.0001
# lads                  	---	  0.0001
# disagreeable          	---	  0.0001
# thumb                 	---	  0.0001
# ollut                 	---	  0.0001
# 15404
# topic 10:
# compromise            	---	  0.0002
# swimming              	---	  0.0001
# bright                	---	  0.0001
# spoke                 	---	  0.0001
# sondern               	---	  0.0001
# apollo                	---	  0.0001
# stir                  	---	  0.0001
# bout                  	---	  0.0001
# towers                	---	  0.0001
# elizabeth             	---	  0.0001
# 15404
# topic 11:
# diamond               	---	  0.0002
# model                 	---	  0.0002
# practised             	---	  0.0001
# appears               	---	  0.0001
# afore                 	---	  0.0001
# aught                 	---	  0.0001
# laquelle              	---	  0.0001
# searching             	---	  0.0001
# tribunal              	---	  0.0001
# colonial              	---	  0.0001
# 15404
# topic 12:
# admirable             	---	  0.0002
# urgent                	---	  0.0002
# parliament            	---	  0.0002
# match                 	---	  0.0002
# laid                  	---	  0.0001
# attachment            	---	  0.0001
# performance           	---	  0.0001
# donc                  	---	  0.0001
# darling               	---	  0.0001
# rash                  	---	  0.0001
# 15404
# topic 13:
# acres                 	---	  0.0002
# field                 	---	  0.0002
# identical             	---	  0.0002
# elapsed               	---	  0.0002
# appreciation          	---	  0.0002
# applause              	---	  0.0001
# online                	---	  0.0001
# seiner                	---	  0.0001
# promotion             	---	  0.0001
# whistle               	---	  0.0001
# 15404
# topic 14:
# johnny                	---	  0.0002
# times                 	---	  0.0001
# think                 	---	  0.0001
# daughter              	---	  0.0001
# toen                  	---	  0.0001
# resemblance           	---	  0.0001
# recognition           	---	  0.0001
# additional            	---	  0.0001
# seen                  	---	  0.0001
# onder                 	---	  0.0001
# 15404
# topic 15:
# project               	---	  0.0240
# gutenberg             	---	  0.0236
# work                  	---	  0.0109
# works                 	---	  0.0083
# electronic            	---	  0.0070
# foundation            	---	  0.0065
# states                	---	  0.0062
# donations             	---	  0.0056
# terms                 	---	  0.0053
# copyright             	---	  0.0049
# 15404
# topic 16:
# bon                   	---	  0.0002
# frantic               	---	  0.0002
# key                   	---	  0.0002
# bullet                	---	  0.0002
# helen                 	---	  0.0001
# foi                   	---	  0.0001
# crush                 	---	  0.0001
# little                	---	  0.0001
# oregon                	---	  0.0001
# animals               	---	  0.0001
# 15404
# topic 17:
# adapted               	---	  0.0002
# hills                 	---	  0.0002
# blessing              	---	  0.0001
# arnold                	---	  0.0001
# arising               	---	  0.0001
# salary                	---	  0.0001
# convert               	---	  0.0001
# sheets                	---	  0.0001
# remain                	---	  0.0001
# retirement            	---	  0.0001
# 15404
# topic 18:
# agricultural          	---	  0.0002
# streets               	---	  0.0001
# eminent               	---	  0.0001
# battery               	---	  0.0001
# saved                 	---	  0.0001
# theirs                	---	  0.0001
# carpet                	---	  0.0001
# swords                	---	  0.0001
# crack                 	---	  0.0001
# imprisonment          	---	  0.0001
# 15404
# topic 19:
# spot                  	---	  0.0001
# blushed               	---	  0.0001
# sounded               	---	  0.0001
# silent                	---	  0.0001
# darkened              	---	  0.0001
# forgot                	---	  0.0001
# sombre                	---	  0.0001
# income                	---	  0.0001
# crushed               	---	  0.0001
# detailed              	---	  0.0001
# 15404
